# %% [markdown]
# <a href="https://colab.research.google.com/github/biniyam-mulugeta/final/blob/main/SVM_ROC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import numpy as np 
import keras
from keras.models import Model
from keras.layers import Flatten,concatenate,GlobalAveragePooling2D,DepthwiseConv2D,Add#,Dense,Dropout,Conv2D
from keras.applications import densenet,mobilenet, mobilenet_v2,efficientnet#densenetmobilenet_v2#,efficientnet,vgg16,densenet
from keras.applications import vgg19,resnet
#from keras_preprocessing import image
#from keras_preprocessing.image import ImageDataGenerator
#from keras.utils.all_utils import to_categorical
from sklearn import preprocessing
from skimage.filters import threshold_otsu
import cv2
from pathlib import Path
import os
import glob
import matplotlib.pyplot as plt
#import seaborn as sns
#import zipfile
# %matplotlib inline

# %%
from sklearn.decomposition import PCA
from sklearn.svm import SVC
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,AdaBoostClassifier
from sklearn.model_selection import KFold,StratifiedKFold,cross_val_score,GridSearchCV,StratifiedShuffleSplit
from sklearn.metrics import classification_report,f1_score,accuracy_score,confusion_matrix,ConfusionMatrixDisplay
from skimage import io

# %%
from keras.layers import Flatten,concatenate,GlobalAveragePooling2D,Input,Dense,Dropout,Conv2D,Activation,MaxPooling2D,BatchNormalization
from keras.layers import MaxPool2D,AveragePooling2D

# %%
import pandas as pd

# %%
SIZE = 32
data_image = []
data_label = []
for dir_path in glob.glob("/content/drive/My Drive/coffee_dataset/*"):
    label = dir_path.split("\\")[-1]
    print(label)
    for img_path in glob.glob(os.path.join(dir_path,"*.jpg")):
        print(img_path)
        img = cv2.imread(img_path,cv2.IMREAD_COLOR)
        img = cv2.resize(img,(SIZE,SIZE))
        img = cv2.cvtColor(img,cv2.COLOR_RGB2BGR)
        
        img = cv2.GaussianBlur(img,(5,5),0)
  
        #img = otsu_segmentation(img)]

        data_image.append(img)
        data_label.append(label)
data_image = np.array(data_image)
data_label = np.array(data_label)
# Out:
# Streaming output truncated to the last 5000 lines.
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_4.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_5.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_6.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_7.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/456_8.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/458.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/458_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/458_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/458_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/458_4.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/460.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/461.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/461_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/461_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/463.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/464.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/464_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/464_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/467.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/467_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/468.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/468_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/468_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/469.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/471.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/472.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/472_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/472_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/473.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/473_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/474.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/475.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/475_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/475_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/475_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476_4.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/476_7.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/477_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/477.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/479.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/479_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/479_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/480.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/482.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/482_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/483.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/483_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/483_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/484.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/484_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/486.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/487.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/487_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/487_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/487_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/488.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/488_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/488_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/489.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/489_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/491.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/493.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/495.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/495_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/496.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/496_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/497.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/497_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/497_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/497_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/500.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/500_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/500_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/500_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/502.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/502_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/502_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/502_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/503.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/503_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/506.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/506_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/506_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/506_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/507.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/507_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/507_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/507_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/509.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/509_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/509_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/509_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/510.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/510_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/511.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/511_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/511_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/511_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/513.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/513_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/514.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/515.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/515_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/515_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/515_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/516.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/519.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/519_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/519_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/519_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/5194.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/521.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/523.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/524.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/524_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/524_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/524_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/524_4.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/526.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/526_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/526_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/528.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/529.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/531.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/531_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/531_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/532.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/532_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/532_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/532_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_4.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_5.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_6.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_7.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/533_8.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/534.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/534_1.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/534_2.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro/534_3.jpg
# /content/drive/My Drive/coffee_dataset/phoma_cro
jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_31.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_32.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_33.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_34.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_35.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_41.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_42.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_43.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_44.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_45.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_51.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_52.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_53.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_54.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/92_55.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/94_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_7.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/97_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_7.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_8.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_31.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_32.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_33.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_34.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/99_35.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_7.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/100_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_31.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_32.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_33.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_34.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_35.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_41.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_42.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_43.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_44.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_45.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_51.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_52.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_53.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_54.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_55.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_61.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_62.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_63.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_64.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_65.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_7.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_8.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_9.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_10.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/101_16.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_11.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_12.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_13.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_1.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_14.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_15.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_21 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_21.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_22 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_22.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_23 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_23.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_2 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_2.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_24 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_24.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_25 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_25.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_31 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_31.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_32.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_33.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_3 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_3.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_34.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_35.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_41.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_42.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_43.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_4.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_44.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_45.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_51.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_52.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_53.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_5.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_54.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_55.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_61.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_62.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_63.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_6.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_64.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_65.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_71.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_72.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_73.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_7.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_74.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_75.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_8.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_9.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_10.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_16 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_16.jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_17 (1).jpg
# /content/drive/My Drive/coffee_dataset/cwd_new_crop/102_17.jpg

# %%
le = preprocessing.LabelEncoder()
le.fit(data_label)
train_labe_encoded = le.transform(data_label)

# %%
x_train,y_train = data_image,train_labe_encoded
x_train = x_train/255.0

# %% [markdown]
# ### train test validate splite

# %%
from sklearn.model_selection import train_test_split

# %%
x_tr,x_te,y_tr,y_te = train_test_split(x_train,train_labe_encoded,test_size=0.20,shuffle=True,random_state=42,stratify=train_labe_encoded)

# %%
print(x_tr.shape,'----',y_tr.shape)
print(x_te.shape,'----',y_te.shape)
# Out:
# (5653, 32, 32, 3) ---- (5653,)
# (1414, 32, 32, 3) ---- (1414,)

# %%
#x_v,x_tes,y_v,y_tes = train_test_split(x_te,y_te,test_size=0.5,shuffle=True,random_state=42,stratify=y_te)

# %%
shape = (32,32,3)

# %% [markdown]
# ### GoogleNet

# %%
def inception_module(x,filters_1x1,filters_3x3_reduce,filters_3x3,filters_5x5_reduce,filters_5x5,filters_pool_proj,name=None):
    
    conv_1x1 = Conv2D(filters_1x1, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    
    conv_3x3 = Conv2D(filters_3x3_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_3x3 = Conv2D(filters_3x3, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_3x3)

    conv_5x5 = Conv2D(filters_5x5_reduce, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(x)
    conv_5x5 = Conv2D(filters_5x5, (3, 3), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(conv_5x5)

    pool_proj = MaxPool2D((3, 3), strides=(1, 1), padding='same')(x)
    pool_proj = Conv2D(filters_pool_proj, (1, 1), padding='same', activation='relu', kernel_initializer=kernel_init, bias_initializer=bias_init)(pool_proj)

    output = concatenate([conv_1x1, conv_3x3, conv_5x5, pool_proj], axis=3, name=name)
    
    return output

# %%
kernel_init = keras.initializers.he_uniform()
bias_init = keras.initializers.Constant(value=0.2)

# %%
input_layer = Input(shape=(32, 32, 3))

x = Conv2D(64, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_1_7x7/2', kernel_initializer=kernel_init, bias_initializer=bias_init)(input_layer)
x = MaxPool2D((2, 2), padding='same', strides=(1, 1), name='max_pool_1_3x3/2')(x)
x = Conv2D(64, (1, 1), padding='same', strides=(2, 2), activation='relu', name='conv_2a_3x3/1')(x)
x = Conv2D(128, (3, 3), padding='same', strides=(1, 1), activation='relu', name='conv_2b_3x3/1')(x)
x = MaxPool2D((2, 2), padding='same', strides=(2, 2), name='max_pool_2_3x3/2')(x)

x = inception_module(x,
                     filters_1x1=32,
                     filters_3x3_reduce=96,
                     filters_3x3=128,
                     filters_5x5_reduce=16,
                     filters_5x5=32,
                     filters_pool_proj=32,
                     name='inception_3a')

x = inception_module(x,
                     filters_1x1=64,
                     filters_3x3_reduce=128,
                     filters_3x3=192,
                     filters_5x5_reduce=32,
                     filters_5x5=96,
                     filters_pool_proj=64,
                     name='inception_3b')


x = GlobalAveragePooling2D(name='avg_pool_5_3x3/1')(x)

x = Dropout(0.4)(x)

x = Dense(6, activation='softmax', name='output')(x)
google_net = Model(input_layer,x, name='inception_v1')
# Out:
# /usr/local/lib/python3.8/dist-packages/keras/initializers/initializers_v2.py:120: UserWarning: The initializer HeUniform is unseeded and being called multiple times, which will return identical values  each time (even if the initializer is unseeded). Please update your code to provide a seed to the initializer, or avoid using the same initalizer instance more than once.
#   warnings.warn(

# %% [markdown]
# ### ResNet

# %%
from keras.layers import add
stride = 1
CHANNEL_AXIS = 3

def res_layer(x ,filters,pooling = False,dropout = 0.0):
    temp = x
    temp = Conv2D(filters,(3,3),strides = stride,padding = "same",kernel_initializer='he_uniform')(temp)
    temp = BatchNormalization(axis = CHANNEL_AXIS)(temp)
    temp = Activation("relu")(temp)
    temp = Conv2D(filters,(3,3),strides = stride,padding = "same",kernel_initializer='he_uniform')(temp)

    x = add([temp,Conv2D(filters,(3,3),strides = stride,padding = "same",kernel_initializer='he_uniform')(x)])
    if pooling:
        x = MaxPooling2D((2,2))(x)
    if dropout != 0.0:
        x = Dropout(dropout)(x)
    x = BatchNormalization(axis = CHANNEL_AXIS)(x)
    x = Activation("relu")(x)
    return x

# %%
inp = Input(shape = shape)
x = inp
x = Conv2D(16,(3,3),strides = stride,padding = "same")(x)
x = BatchNormalization(axis = CHANNEL_AXIS)(x)
x = Activation("relu")(x)
x = res_layer(x,32,dropout = 0.2)
x = res_layer(x,64,dropout = 0.3)
x = GlobalAveragePooling2D()(x)
x = Dropout(0.23)(x)
x = Dense(7,activation = "softmax")(x)

resnet_model = Model(inp,x,name = "Resnet")

# %% [markdown]
# ### proposed model

# %%
out1 = google_net.get_layer(index = -3).output
out2 = resnet_model.get_layer(index= -3).output
out = concatenate([out1,out2])
"""
out = Dense(64,activation='relu')(out)
out = Dropout(0.340)(out)
out = Dense(128,activation='relu')(out)
out = Dropout(0.45)(out)
out = Dense(256,activation='relu')(out)
#out = Dropout(0.50)(out)


output = Dense(8,activation='softmax')(out)"""
# Out:
# "\nout = Dense(64,activation='relu')(out)\nout = Dropout(0.340)(out)\nout = Dense(128,activation='relu')(out)\nout = Dropout(0.45)(out)\nout = Dense(256,activation='relu')(out)\n#out = Dropout(0.50)(out)\n\n\noutput = Dense(8,activation='softmax')(out)"

# %%
e_model = Model(inputs = [google_net.input,resnet_model.input],outputs = out)

# %%
print("Feature extraction ...Training")
prediction_tr = np.array(e_model.predict([x_tr,x_tr]))
prediction_tr.shape
# Out:
# Feature extraction ...Training
# 177/177 [==============================] - 8s 6ms/step
# (5653, 480)

# %%
Xtrain = np.reshape(prediction_tr, (prediction_tr.shape[0], prediction_tr.shape[1]))

# %%
#print("Feature extraction ...validation")
#prediction_v = np.array(e_model.predict([x_v,x_v]))
#prediction_v.shape

# %%
#Xvalidate = np.reshape(prediction_v, (prediction_v.shape[0], prediction_v.shape[1]))

# %%
print("Feature extraction ...Testing")
prediction_tes = np.array(e_model.predict([x_te,x_te]))
# Out:
# Feature extraction ...Testing
# 45/45 [==============================] - 0s 10ms/step

# %%
Xtest = np.reshape(prediction_tes, (prediction_tes.shape[0], prediction_tes.shape[1]))

# %%
print('\tFeatures training shape: ', Xtrain.shape)
#print('\tFeatures testing shape: ', Xvalidate.shape)
print('\tFeatures testing shape: ', Xtest.shape)
# Out:
# 	Features training shape:  (5653, 480)
# 	Features testing shape:  (1414, 480)

# %%
C_range = np.logspace(-2, 10, 10)
gamma_range = np.logspace(-9, 3,10)
param_grid = dict(gamma=gamma_range, C=C_range)
cv = StratifiedKFold(n_splits=3,shuffle=True,random_state=42)
grid = GridSearchCV(SVC(), param_grid=param_grid, cv=cv)
grid.fit(Xtrain, y_tr)
# Out:
# GridSearchCV(cv=StratifiedKFold(n_splits=3, random_state=42, shuffle=True),
#              estimator=SVC(),
#              param_grid={'C': array([1.00000000e-02, 2.15443469e-01, 4.64158883e+00, 1.00000000e+02,
#        2.15443469e+03, 4.64158883e+04, 1.00000000e+06, 2.15443469e+07,
#        4.64158883e+08, 1.00000000e+10]),
#                          'gamma': array([1.00000000e-09, 2.15443469e-08, 4.64158883e-07, 1.00000000e-05,
#        2.15443469e-04, 4.64158883e-03, 1.00000000e-01, 2.15443469e+00,
#        4.64158883e+01, 1.00000000e+03])})

# %%
print(
    "The best parameters are %s with a score of %0.2f"
    % (grid.best_params_, grid.best_score_)
)
# Out:
# The best parameters are {'C': 2154.4346900318824, 'gamma': 0.1} with a score of 0.96

# %%
df = pd.DataFrame(grid.cv_results_)
mask = df['rank_test_score']<10
newdf = df[mask]
newdf[['param_C','param_gamma','mean_test_score','std_test_score','rank_test_score']]
# Out:
#              param_C param_gamma  mean_test_score  std_test_score  \
# 46        2154.43469         0.1         0.956837        0.001334
# 55      46415.888336    0.004642         0.955599        0.002170
# 56      46415.888336         0.1         0.949054        0.003704
# 64         1000000.0    0.000215         0.949408        0.001079
# 65         1000000.0    0.004642         0.949054        0.003112
# 66         1000000.0         0.1         0.949054        0.003704
# 76   21544346.900319         0.1         0.949054        0.003704
# 86  464158883.361277         0.1         0.949054        0.003704
# 96     10000000000.0         0.1         0.949054        0.003704
#
#     rank_test_score
# 46                1
# 55                2
# 56                5
# 64                3
# 65                4
# 66                5
# 76                5
# 86                5
# 96                5

# %% [markdown]
# ### SVM

# %%
labeles = ['CBD','CB_Healthy','CWD','Leaf Healthy','Cercospora','Mold','Phoma','CLR']
target_names = ['CBD','CB_Healthy','CWD','Healthy','Cercospora','Mold','Phoma','CLR']

# %%
svm = SVC(kernel='rbf',C=2154.4346900318824,gamma=0.1)
svm.fit(Xtrain, y_tr)
# Out:
# SVC(C=2154.4346900318824, gamma=0.1)

# %%
    predict_train = svm.predict(Xtrain)
    fig,ax = plt.subplots(figsize=(8,8))
    acc = accuracy_score(predict_train, np.ravel(y_tr, order='C'))
    print("\tTraining Accuracy of SVM: %0.4f" % acc)
    cm = confusion_matrix(y_tr, predict_train, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Training")
    plt.show()
# Out:
# 	Training Accuracy of SVM: 0.9920

# %%
    print('predicting values for SVM Testing')
    predict_validate = svm.predict(Xvalidate)
    fig,ax = plt.subplots(figsize=(8,8))
    acc = accuracy_score(predict_validate, np.ravel(y_v, order='C'))
    print("\tTesting Accuracy of SVM: %0.4f" % acc)
    cm = confusion_matrix(y_v, predict_validate, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Testing")
    plt.show()
# Out:
# predicting values for SVM Testing
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-6f20540cebc5> in <module>
#       1 print('predicting values for SVM Testing')
# ----> 2 predict_validate = svm.predict(Xvalidate)
#       3 fig,ax = plt.subplots(figsize=(8,8))
#       4 acc = accuracy_score(predict_validate, np.ravel(y_v, order='C'))
#       5 print("\tTesting Accuracy of SVM: %0.4f" % acc)
#
# NameError: name 'Xvalidate' is not defined

# %%
    print('predicting values for SVM Validation')
    predict_test = svm.predict(Xtest)
    fig,ax = plt.subplots(figsize=(8,8))
    acc = accuracy_score(predict_test, np.ravel(y_tes, order='C'))
    print("\tValidation Accuracy of SVM: %0.4f" % acc)
    cm = confusion_matrix(y_tes, predict_test, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Validation")
    plt.show()

# %%
print('classification report for Testing')
print(classification_report(y_v,predict_validate,target_names=target_names))

# %%
from yellowbrick.classifier import ROCAUC,ConfusionMatrix
def plot_ROC_curve(model, xtrain, ytrain, xtest, ytest):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model, encoder={0:'cbd',1: 'cb_healthy',2: 'CWD',3: 'leaf healthy' ,4: 'Cercospora', 5: 'mold', 6: 'phoma',7 : 'rust'})
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(xtrain, ytrain)
    visualizer.score(xtest, ytest)
    visualizer.show()
    
    return visualizer

# %%
plot_ROC_curve(svm,Xtrain,y_tr,Xtest,y_tes)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7fb09a549550>,
#        encoder={0: 'cbd', 1: 'cb_healthy', 2: 'CWD', 3: 'leaf healthy',
#                 4: 'Cercospora', 5: 'mold', 6: 'phoma', 7: 'rust'},
#        estimator=SVC(C=46415.888336127726, gamma=1000))

# %%
skfolds = StratifiedKFold(n_splits=3,shuffle=True, random_state=42)
#skfolds = KFold(n_splits=3)

# %%
svm = SVC(kernel='rbf',C=2154.43,gamma=0.1)
score = []
i = 0
for trainset,testset in skfolds.split(Xtrain,y_tr):
    predicted_targets = np.array([])
    actual_targets = np.array([])
    accuracy_list = list()
    predicted_train_targets = np.array([])
    actual_train_targets = np.array([])
    accuracy_train_list = list()
    print("folds ", i)
    print(trainset,"having :" , len(trainset))
    print(testset,"having :" , len(testset))

    x_tr,x_te=Xtrain[trainset],Xtrain[testset]
    y_trin,y_test=y_tr[trainset],y_tr[testset]

    #clone_clf = clone(svm)
    svm.fit(x_tr, y_trin)
    predicted_labels = svm.predict(x_te)
    accuracy = accuracy_score(y_test, predicted_labels)
    
    predicted_t_labels = svm.predict(x_tr)
    accuracy_t = accuracy_score(y_trin, predicted_t_labels)
    
    predicted_targets = np.append(predicted_targets, predicted_labels)
    actual_targets = np.append(actual_targets, y_test)
    accuracy_list.append(accuracy)
    
    predicted_train_targets = np.append(predicted_train_targets, predicted_t_labels)
    actual_train_targets = np.append(actual_train_targets, y_trin)
    accuracy_train_list.append(accuracy_t)
    
    print("iteration", i)
    i+=1
# Out:
# folds  0
# [   0    2    4 ... 5649 5651 5652] having : 3768
# [   1    3    8 ... 5645 5648 5650] having : 1885
# iteration 0
# folds  1
# [   1    2    3 ... 5649 5650 5651] having : 3769
# [   0    4    7 ... 5643 5647 5652] having : 1884
# iteration 1
# folds  2
# [   0    1    3 ... 5648 5650 5652] having : 3769
# [   2    5    6 ... 5646 5649 5651] having : 1884
# iteration 2

# %%
labeles = ['CBD','CB_Healthy','CWD','Healthy','Cercospora','Mold','Phoma','CLR']

# %%
    fig,ax = plt.subplots(figsize=(8,8))
    acc = accuracy_score(predicted_t_labels, np.ravel(y_trin, order='C'))
    print("\tTraining Accuracy of SVM: %0.4f" % acc)
    cm = confusion_matrix(actual_train_targets, predicted_train_targets, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Training")
    plt.show()
# Out:
# 	Training Accuracy of SVM: 0.9942

# %%
    fig,ax = plt.subplots(figsize=(8,8))
    acc = accuracy_score(predicted_labels, np.ravel(y_test, order='C'))
    print("\tValidation Accuracy of SVM: %0.4f" % acc)
    
    cm = confusion_matrix(actual_targets, predicted_targets, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Validation")
    plt.show()
# Out:
# 	Validation Accuracy of SVM: 0.9565

# %%
result = svm.predict(Xtest)

acc = accuracy_score(result, np.ravel(y_te, order='C'))
print("\tTesting Accuracy of SVM: %0.4f" % acc)
print(classification_report(y_te,result,target_names=target_names))
# Out:
# 	Testing Accuracy of SVM: 0.9569
#               precision    recall  f1-score   support
#
#          CBD       0.90      0.93      0.91       195
#   CB_Healthy       0.91      0.87      0.89       166
#          CWD       1.00      1.00      1.00       178
#      Healthy       1.00      1.00      1.00       214
#   Cercospora       0.94      0.93      0.93       162
#         Mold       0.98      0.98      0.98       164
#        Phoma       0.98      0.99      0.98       162
#          CLR       0.94      0.95      0.95       173
#
#     accuracy                           0.96      1414
#    macro avg       0.96      0.96      0.96      1414
# weighted avg       0.96      0.96      0.96      1414

# %%
    fig,ax = plt.subplots(figsize=(8,8))
    cm = confusion_matrix(y_te, result, labels=svm.classes_)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=labeles)
    disp.plot(cmap='BuGn',ax = ax,xticks_rotation=45)
    disp.ax_.set_title("SVM Confusion matrix for Testing")
    plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize

# Define class names
class_names = labeles = ['CBD','CB_Healthy','CWD','Leaf Healthy','Cercospora','Mold','Phoma','CLR']

# Define number of classes
num_classes = len(class_names)

# Generate some example data
#y_true = np.array([0, 1, 2, 3, 4, 5, 6, 7, 0, 1, 2, 3, 4, 5, 6, 7])
#y_score = np.random.rand(16, num_classes)  # Replace with your own prediction scores

# Binarize the labels
y_true = label_binarize(y_te, classes=np.arange(num_classes))
y_pre = label_binarize(result, classes=np.arange(num_classes))

# Compute ROC curve and ROC area for each class
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_true[:, i], y_pre[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

# Compute micro-average ROC curve and ROC area
fpr["micro"], tpr["micro"], _ = roc_curve(y_true.ravel(), y_pre.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

# Compute macro-average ROC curve and ROC area
# First aggregate all false positive rates
all_fpr = np.unique(np.concatenate([fpr[i] for i in range(num_classes)]))

# Then interpolate all ROC curves at this points
mean_tpr = np.zeros_like(all_fpr)
for i in range(num_classes):
    mean_tpr += np.interp(all_fpr, fpr[i], tpr[i])

# Finally average it and compute AUC
mean_tpr /= num_classes

fpr["macro"] = all_fpr
tpr["macro"] = mean_tpr
roc_auc["macro"] = auc(fpr["macro"], tpr["macro"])

# Plot ROC curve
plt.figure(figsize=(8,5),dpi=300)
lw = 2
colors = cycle(['blue', 'red', 'green', 'cyan', 'magenta', 'yellow', 'black', 'purple'])
for i, color in zip(range(num_classes), colors):
    plt.plot(fpr[i], tpr[i], color=color, lw=lw, label='ROC curve of {0} (area = {1:0.2f})'
             ''.format(class_names[i], roc_auc[i]))

plt.plot(fpr["micro"], tpr["micro"], color='deeppink', lw=lw, linestyle=':', label='micro-average ROC curve (area = {0:0.2f})'
             ''.format(roc_auc["micro"]))

plt.plot(fpr["macro"], tpr["macro"], color='navy', lw=lw, linestyle=':', label='macro-average ROC curve (area = {0:0.2f})'
             ''.format(roc_auc["macro"]))

plt.plot([0, 1], [0, 1], 'k--', lw=lw)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic curve of SVM')
plt.legend(loc="lower right")
plt.show()

# %%
from yellowbrick.classifier import ROCAUC,ConfusionMatrix

# %%
def plot_ROC_curve(model, xtrain, ytrain, xtest, ytest):

    # Creating visualization with the readable labels
    visualizer = ROCAUC(model, encoder={0:'cbd',1: 'cb_healthy',2:'CWD',3: 'leaf healthy' ,4: 'Cercospora', 5: 'mold', 6: 'phoma',7 : 'rust'})
                                        
    # Fitting to the training data first then scoring with the test data                                    
    visualizer.fit(xtrain, ytrain)
    visualizer.score(xtest, ytest)
    visualizer.show()
    
    return visualizer

# %%
plot_ROC_curve(svm,Xtrain,y_tr,Xtest,y_te)
# Out:
# ROCAUC(ax=<matplotlib.axes._subplots.AxesSubplot object at 0x7f1c601ac590>,
#        encoder={0: 'cbd', 1: 'cb_healthy', 2: 'CWD', 3: 'leaf healthy',
#                 4: 'Cercospora', 5: 'mold', 6: 'phoma', 7: 'rust'},
#        estimator=SVC(C=2154.43, gamma=0.1))
